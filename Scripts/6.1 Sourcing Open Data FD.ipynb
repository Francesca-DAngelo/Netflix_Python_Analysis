# %% [markdown]
# # Netflix Movies and TV shows

# %% [markdown]
# ### 1. Importing Libraries;
# ### 2. Importing Data;
# ### 3. Performing Data Quality checks;
# #### 3.1 Removing duplicates;
# #### 3.2 Finding missing values;
# #### 3.3 Replacing missing values;
# #### 3.4 Dropping unnecessary columns;
# #### 3.5 Other wrangling procedures;
# #### 3.6 Renaming columns;
# #### 3.7 Converting data types;

# %% [markdown]
# # 1. Importing libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# # 2. Importing data

# %%
# Defining a path
path = r'C:\Users\franc\Documents\Netflix Movies and tv shows'

# %%
# Importing the dataset
df_titles = pd.read_csv(os.path.join(path, 'Data','Original Data','titles.csv'), index_col = False)

# %%
# Checking the data sets
df_titles.shape
# Out:
# (6137, 15)

# %%
df_titles.head(5)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm82169                                Rocky  MOVIE
# 2   tm17823                               Grease  MOVIE
# 3  tm191099                            The Sting  MOVIE
# 4   tm69975                             Rocky II  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  When world heavyweight boxing champion, Apollo...          1976
# 2  Australian good girl Sandy and greaser Danny f...          1978
# 3  A novice con man teams up with an acknowledged...          1973
# 4  After Rocky goes the distance with champ Apoll...          1979
#
#   age_certification  runtime                                 genres  \
# 0             TV-MA       51                      ['documentation']
# 1                PG      119                     ['drama', 'sport']
# 2                PG      110                  ['romance', 'comedy']
# 3                PG      129  ['crime', 'drama', 'comedy', 'music']
# 4                PG      119                     ['drama', 'sport']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075148         8.1    588100.0
# 2               ['US']      NaN  tt0077631         7.2    283316.0
# 3               ['US']      NaN  tt0070735         8.3    266738.0
# 4               ['US']      NaN  tt0079817         7.3    216307.0
#
#    tmdb_popularity  tmdb_score
# 0            0.601         NaN
# 1          106.361       7.782
# 2           33.160       7.406
# 3           24.616       8.020
# 4           75.699       7.246

# %% [markdown]
# # 3. Performing Data Quality checks

# %%
# Getting info about the data sets
df_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6137 entries, 0 to 6136
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    6137 non-null   object
#  1   title                 6137 non-null   object
#  2   type                  6137 non-null   object
#  3   description           6114 non-null   object
#  4   release_year          6137 non-null   int64
#  5   age_certification     3394 non-null   object
#  6   runtime               6137 non-null   int64
#  7   genres                6137 non-null   object
#  8   production_countries  6137 non-null   object
#  9   seasons               2306 non-null   float64
#  10  imdb_id               5741 non-null   object
#  11  imdb_score            5669 non-null   float64
#  12  imdb_votes            5653 non-null   float64
#  13  tmdb_popularity       6061 non-null   float64
#  14  tmdb_score            5885 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 719.3+ KB

# %%
df_titles.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   6137.000000  6137.000000  2306.000000  5669.000000  5.653000e+03
# mean    2017.371843    76.381946     2.106678     6.540942  2.115029e+04
# std        6.603620    39.086828     2.716844     1.135944  9.254225e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2017.000000    44.000000     1.000000     5.800000  5.170000e+02
# 50%     2019.000000    80.000000     1.000000     6.600000  2.095000e+03
# 75%     2021.000000   105.000000     2.000000     7.300000  8.884000e+03
# max     2023.000000   225.000000    44.000000     9.600000  2.684317e+06
#
#        tmdb_popularity   tmdb_score
# count      6061.000000  5885.000000
# mean         19.267196     6.633194
# std          51.291407     1.251610
# min           0.009442     0.500000
# 25%           3.381000     6.000000
# 50%           7.580000     6.791000
# 75%          16.523000     7.400000
# max        1078.637000    10.000000

# %% [markdown]
# # 3.1 Removing duplicates

# %%
# Checking for duplicates
df_titles_dups = df_titles[df_titles.duplicated()]

# %%
df_titles_dups
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# No duplicates have been found in the dataset

# %% [markdown]
# # 3.2 Finding missing values

# %%
#Checking for missing values
df_titles.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description               23
# release_year               0
# age_certification       2743
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3831
# imdb_id                  396
# imdb_score               468
# imdb_votes               484
# tmdb_popularity           76
# tmdb_score               252
# dtype: int64

# %% [markdown]
# # 3.3 Replacing missing values;

# %%
# Replacing missing values in "season" column
df_titles['seasons'].fillna(0, inplace=True)

# %%
df_titles.head(5)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm82169                                Rocky  MOVIE
# 2   tm17823                               Grease  MOVIE
# 3  tm191099                            The Sting  MOVIE
# 4   tm69975                             Rocky II  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  When world heavyweight boxing champion, Apollo...          1976
# 2  Australian good girl Sandy and greaser Danny f...          1978
# 3  A novice con man teams up with an acknowledged...          1973
# 4  After Rocky goes the distance with champ Apoll...          1979
#
#   age_certification  runtime                                 genres  \
# 0             TV-MA       51                      ['documentation']
# 1                PG      119                     ['drama', 'sport']
# 2                PG      110                  ['romance', 'comedy']
# 3                PG      129  ['crime', 'drama', 'comedy', 'music']
# 4                PG      119                     ['drama', 'sport']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      0.0  tt0075148         8.1    588100.0
# 2               ['US']      0.0  tt0077631         7.2    283316.0
# 3               ['US']      0.0  tt0070735         8.3    266738.0
# 4               ['US']      0.0  tt0079817         7.3    216307.0
#
#    tmdb_popularity  tmdb_score
# 0            0.601         NaN
# 1          106.361       7.782
# 2           33.160       7.406
# 3           24.616       8.020
# 4           75.699       7.246

# %% [markdown]
# I replaced "Nan" values in "season" column with 0, because they are movies and therefore they don't have seasons

# %% [markdown]
# # 3.4 Dropping unnecessary columns

# %%
# Dropping columns that are not necessary for the analysis
df_titles = df_titles.drop(columns = ['description','imdb_id'])

# %%
# Dropping columns which have too many missing values
df_titles = df_titles.drop(columns = ['age_certification'])

# %%
df_titles.head(5)
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm82169                                Rocky  MOVIE          1976
# 2   tm17823                               Grease  MOVIE          1978
# 3  tm191099                            The Sting  MOVIE          1973
# 4   tm69975                             Rocky II  MOVIE          1979
#
#    runtime                                 genres production_countries  \
# 0       51                      ['documentation']               ['US']
# 1      119                     ['drama', 'sport']               ['US']
# 2      110                  ['romance', 'comedy']               ['US']
# 3      129  ['crime', 'drama', 'comedy', 'music']               ['US']
# 4      119                     ['drama', 'sport']               ['US']
#
#    seasons  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0      1.0         NaN         NaN            0.601         NaN
# 1      0.0         8.1    588100.0          106.361       7.782
# 2      0.0         7.2    283316.0           33.160       7.406
# 3      0.0         8.3    266738.0           24.616       8.020
# 4      0.0         7.3    216307.0           75.699       7.246

# %% [markdown]
# # 3.4 Other wrangling procedures

# %%
# Using the replace function to drop the parenthesis
df_titles['genres'] = df_titles['genres'].str.replace(r'[','').str.replace(r"'",'').str.replace(r']','')
df_titles['genre'] = df_titles['genres'].str.split(',').str[0]
df_titles['production_countries'] = df_titles['production_countries'].str.replace(r"[", '').str.replace(r"'", '').str.replace(r"]", '')
df_titles['country'] = df_titles['production_countries'].str.split(',').str[0]
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_1512\4294131283.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_titles['genres'] = df_titles['genres'].str.replace(r'[','').str.replace(r"'",'').str.replace(r']','')
# C:\Users\franc\AppData\Local\Temp\ipykernel_1512\4294131283.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_titles['production_countries'] = df_titles['production_countries'].str.replace(r"[", '').str.replace(r"'", '').str.replace(r"]", '')

# %%
# Using the lower function to change item to lowercase

df_titles['type'] = df_titles['type'].str.lower()

# %%
df_titles.head(5)
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   show          1945
# 1   tm82169                                Rocky  movie          1976
# 2   tm17823                               Grease  movie          1978
# 3  tm191099                            The Sting  movie          1973
# 4   tm69975                             Rocky II  movie          1979
#
#    runtime                       genres production_countries  seasons  \
# 0       51                documentation                   US      1.0
# 1      119                 drama, sport                   US      0.0
# 2      110              romance, comedy                   US      0.0
# 3      129  crime, drama, comedy, music                   US      0.0
# 4      119                 drama, sport                   US      0.0
#
#    imdb_score  imdb_votes  tmdb_popularity  tmdb_score          genre country
# 0         NaN         NaN            0.601         NaN  documentation      US
# 1         8.1    588100.0          106.361       7.782          drama      US
# 2         7.2    283316.0           33.160       7.406        romance      US
# 3         8.3    266738.0           24.616       8.020          crime      US
# 4         7.3    216307.0           75.699       7.246          drama      US

# %%
# Finding unique values of a column
print(df_titles['country'].unique())
# Out:
# ['US' 'GB' 'EG' 'IN' 'DE' 'CA' 'LB' 'JP' 'AR' '' 'FR' 'IE' 'AU' 'ET' 'HK'
#  'MX' 'CN' 'ES' 'CO' 'SU' 'IT' 'TR' 'NZ' 'DK' 'TW' 'KR' 'RU' 'NG' 'PS'
#  'MY' 'PH' 'ZA' 'MA' 'SE' 'SG' 'KE' 'NO' 'CL' 'SA' 'BR' 'ID' 'IS' 'IL'
#  'PL' 'FI' 'CD' 'RO' 'AE' 'BE' 'NL' 'UA' 'QA' 'SY' 'GL' 'AT' 'BY' 'JO'
#  'VN' 'TN' 'CZ' 'TH' 'GE' 'KH' 'CH' 'CU' 'UY' 'PE' 'PR' 'KW' 'IR' 'PY'
#  'PK' 'HU' 'IQ' 'BD' 'TZ' 'CM' 'KG' 'LU' 'SN' 'BT' 'PT' 'AO' 'GH' 'ZW'
#  'MW' 'GT' 'MU' 'IO' 'BG' 'AF' 'DO' 'PA' 'FO']

# %%
print(df_titles['genre'].unique())
# Out:
# ['documentation' 'drama' 'romance' 'crime' 'fantasy' 'comedy' 'thriller'
#  'action' 'animation' 'family' 'reality' 'scifi' 'western' 'horror' ''
#  'war' 'music' 'history' 'sport']

# %% [markdown]
# # 3.6 Renaming columns

# %%
# Renaming "runtime" column
df_titles.rename(columns = {'runtime' : 'lenght'}, inplace = True)

# %%
df_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6137 entries, 0 to 6136
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    6137 non-null   object
#  1   title                 6137 non-null   object
#  2   type                  6137 non-null   object
#  3   release_year          6137 non-null   int64
#  4   lenght                6137 non-null   int64
#  5   genres                6137 non-null   object
#  6   production_countries  6137 non-null   object
#  7   seasons               6137 non-null   float64
#  8   imdb_score            5669 non-null   float64
#  9   imdb_votes            5653 non-null   float64
#  10  tmdb_popularity       6061 non-null   float64
#  11  tmdb_score            5885 non-null   float64
#  12  genre                 6137 non-null   object
#  13  country               6137 non-null   object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 671.4+ KB

# %% [markdown]
# # 3.7 Converting data types

# %%
# Replacing NaN Values in "imdb_votes" column with 0
df_titles['imdb_votes'].fillna(0, inplace=True)

# %%
# Converting data types
df_titles['imdb_votes']=df_titles['imdb_votes'].astype(int)
df_titles['seasons']=df_titles['seasons'].astype(int)

# %%
# Rounding "tmdb_popularity" and "tmdb_score" values
df_titles['tmdb_popularity'] = round(df_titles['tmdb_popularity'],1)
df_titles['tmdb_score'] = round(df_titles['tmdb_score'],1)

# %%
df_titles.head(5)
# Out:
#          id                                title   type  release_year  lenght  \
# 0  ts300399  Five Came Back: The Reference Films   show          1945      51
# 1   tm82169                                Rocky  movie          1976     119
# 2   tm17823                               Grease  movie          1978     110
# 3  tm191099                            The Sting  movie          1973     129
# 4   tm69975                             Rocky II  movie          1979     119
#
#                         genres production_countries  seasons  imdb_score  \
# 0                documentation                   US        1         NaN
# 1                 drama, sport                   US        0         8.1
# 2              romance, comedy                   US        0         7.2
# 3  crime, drama, comedy, music                   US        0         8.3
# 4                 drama, sport                   US        0         7.3
#
#    imdb_votes  tmdb_popularity  tmdb_score          genre country
# 0           0              0.6         NaN  documentation      US
# 1      588100            106.4         7.8          drama      US
# 2      283316             33.2         7.4        romance      US
# 3      266738             24.6         8.0          crime      US
# 4      216307             75.7         7.2          drama      US

# %%
# Checking the output
df_titles.shape
# Out:
# (6137, 14)

# %%
# Exporting data to csv
df_titles.to_csv(os.path.join(path, 'Data','Prepared Data', 'netflix.csv'))

# %%
# Exporting data to pkl
df_titles.to_pickle(os.path.join(path, 'Data','Prepared Data', 'netflix.pkl'))
